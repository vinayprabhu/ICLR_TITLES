# %%
# %matplotlib inline
import pandas as pd
df_all=pd.read_csv('sub_raw.csv')

# %%
ind_titles=np.arange(0,470,3)
df_titles=df_all.iloc[ind_titles]
df_titles.reset_index(inplace=True,drop=True)

# %%
from wordcloud import WordCloud
import re
from nltk.corpus import stopwords

raw_txt = df_titles.Title.values
titles_str=' '.join(raw_txt )
wordList = re.sub("[^\w]", " ",  titles_str).split()
filtered_words = [word for word in wordList  if word not in stopwords.words('english')]
filt_str=' '.join(filtered_words)


# Generate a word cloud image
wordcloud = WordCloud().generate(filt_str)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(filt_str)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
ind_dates=np.arange(2,470,3)
ax=df_all.iloc[ind_dates].Title.value_counts().plot(kind='barh')
ax.set_xlabel('Number of submissions')
